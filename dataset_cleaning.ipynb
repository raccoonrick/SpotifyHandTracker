# %% [markdown]
# # Dataset Cleaning

# %% [markdown]
# ## Import packages and load dataset

# %%
import pandas
import numpy as np

# %%
df = pandas.read_csv('model/keypoint_classifier/keypoint.csv', on_bad_lines='skip')
labels = pandas.read_csv('model/keypoint_classifier/keypoint_classifier_label.csv', header=None)

# %% [markdown]
# ## View Dataset and Labels

# %%
df
# Out:
#       0  0.0  0.0.1  0.20078740157480315  -0.051181102362204724  \
# 0     0  0.0    0.0             0.206349              -0.043651
# 1     0  0.0    0.0             0.202381              -0.043651
# 2     0  0.0    0.0             0.207171              -0.039841
# 3     0  0.0    0.0             0.206349              -0.039683
# 4     0  0.0    0.0             0.206349              -0.047619
# ...  ..  ...    ...                  ...                    ...
# 5010  5  0.0    0.0             0.219595              -0.060811
# 5011  5  0.0    0.0             0.198795              -0.105422
# 5012  5  0.0    0.0             0.162500              -0.140625
# 5013  5  0.0    0.0             0.145215              -0.174917
# 5014  5  0.0    0.0             0.119863              -0.202055
#
#       0.3661417322834646  -0.18110236220472442  0.484251968503937  \
# 0               0.376984             -0.162698           0.507937
# ...

# %%
labels
# Out:
#             0
# 0        Open
# 1       Close
# 2         Erm
# 3          OK
# 4  Peace Sign
# 5    Fuck You

# %% [markdown]
# ## Get rows by label

# %%
df.iloc[:,0]

# Get rows where label is 0
df[df.iloc[:, 0] != 3].iloc[:, 0].value_counts()
# Out:
# 0
# 1    1572
# 0    1521
# 2    1356
# 5     149
# 4      80
# Name: count, dtype: int64
